# %%
from selenium import webdriver
DRIVER_PATH = 'D:/Software/chromedriver'
wd = webdriver.Chrome(executable_path=DRIVER_PATH)

# %%
import time
def fetch_image_urls(query:str, max_links_to_fetch:int, wd:webdriver, sleep_between_interactions:int=1):
    def scroll_to_end(wd):
        wd.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(sleep_between_interactions)    
    
    # build the google query
    search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"

    # load the page
    wd.get(search_url.format(q=query))

    image_urls = set()
    image_count = 0
    results_start = 0
    while image_count < max_links_to_fetch:
        scroll_to_end(wd)

        # get all image thumbnail results
        thumbnail_results = wd.find_elements_by_css_selector("img.Q4LuWd")
        number_results = len(thumbnail_results)
        
        print(f"Found: {number_results} search results. Extracting links from {results_start}:{number_results}")
        
        for img in thumbnail_results[results_start:number_results]:
            # try to click every thumbnail such that we can get the real image behind it
            try:
                img.click()
                time.sleep(sleep_between_interactions)
            except Exception:
                continue

            # extract image urls    
            actual_images = wd.find_elements_by_css_selector('img.n3VNCb')
            for actual_image in actual_images:
                if actual_image.get_attribute('src') and 'http' in actual_image.get_attribute('src'):
                    image_urls.add(actual_image.get_attribute('src'))

            image_count = len(image_urls)

            if len(image_urls) >= max_links_to_fetch:
                print(f"Found: {len(image_urls)} image links, done!")
                break
        else:
            print("Found:", len(image_urls), "image links, looking for more ...")
            time.sleep(30)
            return
            load_more_button = wd.find_element_by_css_selector(".mye4qd")
            if load_more_button:
                wd.execute_script("document.querySelector('.mye4qd').click();")

        # move the result startpoint further down
        results_start = len(thumbnail_results)

    return image_urls

# %%
import requests, hashlib, io
from PIL import Image
def persist_image(folder_path:str,url:str):
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - Could not download {url} - {e}")

    try:
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert('RGB')
        file_path = os.path.join(folder_path,hashlib.sha1(image_content).hexdigest()[:10] + '.jpg')
        with open(file_path, 'wb') as f:
            image.save(f, "JPEG", quality=85)
        print(f"SUCCESS - saved {url} - as {file_path}")
    except Exception as e:
        print(f"ERROR - Could not save {url} - {e}")

# %%
import os
def search_and_download(search_term:str,driver_path:str,target_path='./images',number_images=5):
    target_folder = os.path.join(target_path,'_'.join(search_term.lower().split(' ')))

    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    with webdriver.Chrome(executable_path=driver_path) as wd:
        res = fetch_image_urls(search_term, number_images, wd=wd, sleep_between_interactions=0.5)
        
    for elem in res:
        persist_image(target_folder,elem)

# %%
search_term = ['German Shepherd', 'Labrador Retriever', 'Golden Retriever', 'French Bulldog', 'Siberian Husky', 'Dalmatian', 'Shiba Inu', 'Samoyed', 'Cane Corso', 'Goldendoodle']
number_images = 100
for term in search_term:
    search_and_download(search_term=term, driver_path=DRIVER_PATH, number_images=number_images, target_path='./images')

# %%
term = 'Goldendoodle'
number_images = 150
search_and_download(search_term=term, driver_path=DRIVER_PATH, number_images=number_images, target_path='./images')
# Out:
# Found: 100 search results. Extracting links from 0:100
# Found: 150 image links, done!
# SUCCESS - saved https://minidoodledogs.com/wp-content/uploads/2017/11/Teacup-Goldendoodle-Utah-Idaho-New_York-Philadephia-Massachussets-Georgia-Virginai-California-Washington-Goldendoodle-Puppies-Golden-doodle-Dog-0001-1.jpg - as ./images\goldendoodle\95c5826ce6.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQlpEH9p_2TERMv56zlkzz4sS3ixnDMlCv5Aw&usqp=CAU - as ./images\goldendoodle\efe4fd1964.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTjq3KwZm-YijMY14UDAMET3jyBXFTH71vSMA&usqp=CAU - as ./images\goldendoodle\d963604237.jpg
# SUCCESS - saved https://www.trendingbreeds.com/wp-content/uploads/2019/07/Do-Goldendoodles-Like-To-Cuddle-large.jpg - as ./images\goldendoodle\b04521f50a.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSdqeTDQvJ9spXyTQC6_JZMzwgUSBTjoXFMqw&usqp=CAU - as ./images\goldendoodle\b611df062c.jpg
# SUCCESS - saved https://images.crateandbarrel.com/is/image/Crate/GoldendoodleAnimalAdoptSetSHS19/$web_pdp_main_carousel_zoom_low$/190411135100/goldendoodle-stuffed-animal-adoption-set.jpg - as ./images\goldendoodle\fb97ccec20.jpg
# SUCCESS - saved https://images-na.ssl-images-amazon.com/images/I/91U-0XTPh+L.jpg - as ./images\goldendoodle\d2b9ce5455.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTLURYDxBD57Fbch2XNYj8SjLGtrH5esmAqDg&usqp=CAU - as ./images\goldendoodle\c24f739f3c.jpg
# SUCCESS - saved https://i.etsystatic.com/7051074/c/1500/1500/0/0/il/1a3c5e/1709383413/il_300x300.1709383413_8plf.jpg - as ./images\goldendoodle\9121a2fa2a.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSw_J7WANj7a3sI4kiezXXMhSCCVW6Z2xI-mw&usqp=CAU - as ./images\goldendoodle\bc29bd17ea.jpg
# SUCCESS - saved https://i1.wp.com/labradoodlehome.com/wp-content/uploads/2020/02/WHAT-IS-THE-BEST-AGE-TO-BREED-A-GOLDENDOODLE.jpg - as ./images\goldendoodle\e449ed513c.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRcU2fRT282Sr_vWWF4yJUpJw1OBSssd7gXyg&usqp=CAU - as ./images\goldendoodle\9087c04310.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTP3RPBz31j7y6_1A3nzKPVLPEdUuPDrGMvsg&usqp=CAU - as ./images\goldendoodle\bce8770698.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSTZIRMHYOBpqotcamfgZR_gxK8RVErUdeJbQ&usqp=CAU - as ./images\goldendoodle\48da64d690.jpg
# SUCCESS - saved https://yourmoderndad.com/wp-content/uploads/2019/05/standard-goldendoodle-mini-goldendoodle-puppy.png - as ./images\goldendoodle\3e900df950.jpg
# SUCCESS - saved https://dogtime.com/assets/uploads/gallery/goldendoodle-dog-breed-pictures/threequarters-10_2.jpg - as ./images\goldendoodle\f0553bbcf2.jpg
# SUCCESS - saved https://www.oodlelife.com/wp-content/uploads/2020/02/curly-coat-straight-coat-comparison-goldendoodle.jpg - as ./images\goldendoodle\b3064e860c.jpg
# SUCCESS - saved https://media1.s-nbcnews.com/i/newscms/2019_29/1461312/litter-of-puppies-today-inline-190716_c35fa32634ccd1b9e3d45a1054f7fe6e.jpg - as ./images\goldendoodle\151e948c89.jpg
# SUCCESS - saved https://barkforce.com/wp-content/uploads/2017/12/carriage_house_goldendoodle_1.jpg - as ./images\goldendoodle\da38c1ceae.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQtJG2-QZS2fLco_btt45kcc6vhta5uphmEnw&usqp=CAU - as ./images\goldendoodle\6500d68d32.jpg
# SUCCESS - saved https://i.pinimg.com/originals/cb/89/81/cb8981e57ccbeeb5b50f813abdbfe4e2.jpg - as ./images\goldendoodle\847d675a48.jpg
# SUCCESS - saved https://m.media-amazon.com/images/I/51uCIsyNUsL._SL500_.jpg - as ./images\goldendoodle\6fe68bd694.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTRzsnBWrgd0z7bxqixeoaTDX3zuxKhakxvIA&usqp=CAU - as ./images\goldendoodle\4da8fc95a8.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTzPW5hfFx7qNDvqKCi4xdExYtHrBMf7U8dRA&usqp=CAU - as ./images\goldendoodle\f9fcdfd797.jpg
# SUCCESS - saved https://minidoodledogs.com/wp-content/uploads/bb-plugin/cache/Micro_Goldendoodles-Mini_Doodle_Dogs-Teacup_Doodle_Dogs-Micro_Goldendoodle_Puppies_for_sale_near_me-Micro_Golden_doodles-13-1024x1024-circle.jpg - as ./images\goldendoodle\fc6d14badd.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSlpbpXzN6N18cIHGon12S9nCQLtraKv_5T4g&usqp=CAU - as ./images\goldendoodle\f2e13d587d.jpg
# SUCCESS - saved https://www.hillspet.ca/content/dam/cp-sites/hills/hills-pet/en_us/exported/dog-care/Skyword/images/goldendoodle-in-grass-SW.jpg - as ./images\goldendoodle\19b7415d19.jpg
# SUCCESS - saved https://thehappypuppysite.com/wp-content/uploads/2019/01/Goldendoodle-Temperament-long.jpg - as ./images\goldendoodle\7ff27c7f82.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQA95zMJSx522VWhHLd-1J0OsWeg7s6-PXtvg&usqp=CAU - as ./images\goldendoodle\a5b59062b3.jpg
# SUCCESS - saved https://www.chiangraitimes.com/wp-content/uploads/2020/10/Seven-Benefits-of-Having-a-Golden-Doodle-Around-Your-Kids-1000x600.jpg - as ./images\goldendoodle\2f41a6519f.jpg
# SUCCESS - saved https://www.loveyourdog.com/wp-content/uploads/2019/07/Mini-Goldendoodle.jpg - as ./images\goldendoodle\1a0e28edba.jpg
# SUCCESS - saved https://www.rover.com/blog/wp-content/uploads/2019/03/teddy-goldendoodle-puppy.jpg - as ./images\goldendoodle\786c8beaa9.jpg
# SUCCESS - saved https://image.shutterstock.com/image-photo/golden-doodle-puppy-playing-ball-260nw-1723968841.jpg - as ./images\goldendoodle\f7fcf865ae.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRibcSJyD58Ybng9Cue_no-ysejgtBegDm3RQ&usqp=CAU - as ./images\goldendoodle\f71ef6c5f1.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTDZ6pgz6cZAFJtVoES9dMmvyjjQAg19IaSvg&usqp=CAU - as ./images\goldendoodle\48a48c51ac.jpg
# SUCCESS - saved https://8wlfu1bd3k93zuvpx2tatbdw-wpengine.netdna-ssl.com/wp-content/uploads/IMG_2313-267x400.jpg - as ./images\goldendoodle\75ca3ff994.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRFYXWOdrjSdZLl63ng3-pvSmUKoYa1007SLw&usqp=CAU - as ./images\goldendoodle\6b18aeeb8c.jpg
# SUCCESS - saved https://i1.wp.com/www.happygodoodle.com/wp-content/uploads/2019/06/red-goldendoodle-adult-chloe.jpg?resize=840%2C560&ssl=1 - as ./images\goldendoodle\cacd674f2b.jpg
# SUCCESS - saved https://i0.wp.com/minigoldendoodlepuppies.ca/wp-content/uploads/2018/08/mini-golden-doodle-toronto-j-small.jpg?fit=600%2C500&ssl=1&is-pending-load=1 - as ./images\goldendoodle\1b4c772bb6.jpg
# SUCCESS - saved https://images.squarespace-cdn.com/content/v1/5c633e877fdcb88882c06b25/1558230075375-1KKRHBYB3H4V3GI9LIW0/ke17ZwdGBToddI8pDm48kFkjSgSWnctqUo4LS-tepwV7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z4YTzHvnKhyp6Da-NYroOW3ZGjoBKy3azqku80C789l0ouw-8l5B_J38LMU7OZFvYe-5mCm9SQEgXUsOz2zDet-eLF4bWS7yiAEfsEEl-rDRw/Cooper5.jpg?format=2500w - as ./images\goldendoodle\77c1124885.jpg
# SUCCESS - saved https://www.dogbreedinfo.com/images32/MiniatureMiniGoldendoodleBentley6MonthsOld45pounds2.jpg - as ./images\goldendoodle\51773cac14.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTa3zQ16XG-W60rFH1WZA713G0lYeUcWFw1jg&usqp=CAU - as ./images\goldendoodle\dbe0df25bb.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQCIPro9UaqVxcladtnJt3M3bbIsl2cQF4OXQ&usqp=CAU - as ./images\goldendoodle\8835c3a60c.jpg
# SUCCESS - saved https://images-na.ssl-images-amazon.com/images/I/719N9AZC3RL.jpg - as ./images\goldendoodle\7733f3bdcb.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRm9OvjhPN8lpxBzAaFAj9ycuO9Kcd4jE_3sQ&usqp=CAU - as ./images\goldendoodle\076fcb1a86.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRiDLYnRZmXUxKQbxSuG8zG8W4wUp5Hmbo-Tw&usqp=CAU - as ./images\goldendoodle\09fe6b3af6.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSA32MIccQRJa8jEixFDNVEzHHXxdhL_FjkHQ&usqp=CAU - as ./images\goldendoodle\63816bc8c6.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSqWdCBjaC3GfmgbyzomsjGdlqH-fOzjQ6eSA&usqp=CAU - as ./images\goldendoodle\b90e22e5e2.jpg
# SUCCESS - saved https://vetstreet-brightspot.s3.amazonaws.com/9f/7b/529041e64c0685caf9d5dc6b3c1e/Goldendoodle-AP-0EMSZN-645sm11514.jpg - as ./images\goldendoodle\676e8e62c3.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSUytPM9CVWi3t0P6gO45IJt2tpvzoBzq1rBQ&usqp=CAU - as ./images\goldendoodle\d25d67d490.jpg
# ERROR - Could not save https://loverdoodles.com/wp-content/uploads/2019/08/Goldendoodle2.png - cannot identify image file <_io.BytesIO object at 0x0000027E6F162AE0>
# SUCCESS - saved https://uptownpuppies.com/wp-content/uploads/2017/05/standard-1.jpg - as ./images\goldendoodle\b412722597.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRu7O9WIEp4iubwgauXpRGlY3Bqu_9F4vu0BA&usqp=CAU - as ./images\goldendoodle\e4dccada76.jpg
# SUCCESS - saved https://www.k9web.com/wp-content/uploads/2019/03/Miniature-Goldendoodle-7.jpg - as ./images\goldendoodle\1e639496d5.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQSxY1mAFQcovLCXfpCEhRg9_1sUb9O6bYbEA&usqp=CAU - as ./images\goldendoodle\84d0603c9d.jpg
# SUCCESS - saved https://i.pinimg.com/originals/16/71/98/167198b6813204933f5c682925d0c08b.jpg - as ./images\goldendoodle\0bbd980041.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSEQA94cZFoof3QNjrz1ZsAGHFVT_2bq8LUjA&usqp=CAU - as ./images\goldendoodle\88bdcf05d1.jpg
# SUCCESS - saved https://vetstreet.brightspotcdn.com/dims4/default/61ede8e/2147483647/crop/0x0%2B0%2B0/resize/645x380/quality/90/?url=https%3A%2F%2Fvetstreet-brightspot.s3.amazonaws.com%2Fa5%2F187ce0a8b411e0a0d50050568d634f%2Ffile%2Fgoldendoodle-3-645mk070111.jpg - as ./images\goldendoodle\0b846a3260.jpg
# SUCCESS - saved https://i.ytimg.com/vi/qV_SYEn2Lkg/maxresdefault.jpg - as ./images\goldendoodle\a5d29cc530.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT2js8bHk3h5Fqb88zcDPGd2NzypDPAuzAjGw&usqp=CAU - as ./images\goldendoodle\5a32111b97.jpg
# SUCCESS - saved https://www.thesprucepets.com/thmb/6ilfDZWPTJ-eJLDemUiHm-hatRc=/1080x716/filters:no_upscale():max_bytes(150000):strip_icc()/9_Goldentubby-5b27119743a103003749b2a6.jpg - as ./images\goldendoodle\5bd0daca91.jpg
# SUCCESS - saved https://i.ytimg.com/vi/ORiG5D_JwIs/hqdefault.jpg - as ./images\goldendoodle\0e14c02f25.jpg
# SUCCESS - saved https://welovedoodles.com/wp-content/uploads/2020/04/goldendoodle-sizes-1024x961.jpg - as ./images\goldendoodle\95263e9343.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTH7OGaBdxqNwb58_nM_HT92D0vZ80rP5EHtg&usqp=CAU - as ./images\goldendoodle\d8df366021.jpg
# SUCCESS - saved https://vetstreet.brightspotcdn.com/dims4/default/d97d0b5/2147483647/crop/0x0%2B0%2B0/resize/645x380/quality/90/?url=https%3A%2F%2Fvetstreet-brightspot.s3.amazonaws.com%2Fb8%2Fb64ed0a8b411e0a0d50050568d634f%2Ffile%2Fgoldendoodle-4-645mk070111.jpg - as ./images\goldendoodle\50b0260738.jpg
# SUCCESS - saved https://trupanion.com/-/media/trupanion/images/breed--guide--new/goldendoodle/goldendoodle-hero-m.jpg - as ./images\goldendoodle\1e607b452e.jpg
# SUCCESS - saved https://heartyk9s.ca/resources/lily-improv.jpg - as ./images\goldendoodle\c5526b9bf4.jpg
# SUCCESS - saved https://i.etsystatic.com/6034210/r/il/3116a1/1116691900/il_570xN.1116691900_rp18.jpg - as ./images\goldendoodle\787e861b0d.jpg
# SUCCESS - saved https://i.pinimg.com/originals/c4/07/9e/c4079e4f15caa9ec97cfa1d64baa8d7c.jpg - as ./images\goldendoodle\7c1ac049d8.jpg
# SUCCESS - saved https://epi.azureedge.net/website-images/images/default-album/goldendoodle.png?sfvrsn=f290d37b_2 - as ./images\goldendoodle\0d52e22e0e.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQPl_t8EFha7htGT2GSZhW67MvIAx-EeKf0uQ&usqp=CAU - as ./images\goldendoodle\786a7b9b72.jpg
# SUCCESS - saved https://cdn.petmoo.com/wp-content/uploads/2018/06/Golden-Doodle-990x556.jpg - as ./images\goldendoodle\2fd699b2c3.jpg
# SUCCESS - saved https://media.istockphoto.com/photos/goldendoodle-puppy-picture-id898256014 - as ./images\goldendoodle\0c755c4256.jpg
# SUCCESS - saved https://animalso.com/wp-content/uploads/2017/06/Miniature-Goldendoodle-372x372.jpg - as ./images\goldendoodle\5621bef626.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTQhqFek_79nF2wOPqiBci5plrWfeY4NVHx_w&usqp=CAU - as ./images\goldendoodle\906db2aeaa.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSz-aB0bm0e9_AhyLhlDdACKrG4AwMymWYchw&usqp=CAU - as ./images\goldendoodle\a4204c1c02.jpg
# SUCCESS - saved https://animalcorner.org/wp-content/uploads/2020/05/Goldendoodle-2-1024x683.jpg - as ./images\goldendoodle\0c97b3f59c.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSXOfePNec8Pkgu0sqI-E6KpA_HbzpSLLmI7A&usqp=CAU - as ./images\goldendoodle\7114b09b80.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSFsPhvKNrNmUHooNL3VXzXtl0OMwd4OoWWfw&usqp=CAU - as ./images\goldendoodle\d2fb208b31.jpg
# SUCCESS - saved https://i.ytimg.com/vi/S6-KliEgzsM/maxresdefault.jpg - as ./images\goldendoodle\02a8353986.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQQYZ47WlVbm2VgoS1ZVQV0mx9fURQJzQgp7Q&usqp=CAU - as ./images\goldendoodle\c49f38b121.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcToHqa_Hxzi3E0SrcUXfglDk09nL9T7-eKGeA&usqp=CAU - as ./images\goldendoodle\af47709c9e.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTlEpAxII84vn1S18oQcYKp4E0aMmBWAMzzWA&usqp=CAU - as ./images\goldendoodle\5ed3eb3fc8.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPT0_JAY3CFfUec9n00CytnnEYFsA8sP293A&usqp=CAU - as ./images\goldendoodle\f7dc52aeab.jpg
# SUCCESS - saved https://images.squarespace-cdn.com/content/v1/5c633e877fdcb88882c06b25/1573867547773-BUIWVJ77E5Y7CHN7I62Q/ke17ZwdGBToddI8pDm48kDHPSfPanjkWqhH6pl6g5ph7gQa3H78H3Y0txjaiv_0fDoOvxcdMmMKkDsyUqMSsMWxHk725yiiHCCLfrh8O1z4YTzHvnKhyp6Da-NYroOW3ZGjoBKy3azqku80C789l0mwONMR1ELp49Lyc52iWr5dNb1QJw9casjKdtTg1_-y4jz4ptJBmI9gQmbjSQnNGng/Carter9.jpg - as ./images\goldendoodle\143f9c6b91.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQbNpb8sVzLHVwdBqdUEjqy49YxBHMKRsBROg&usqp=CAU - as ./images\goldendoodle\381f338fb4.jpg
# SUCCESS - saved https://i1.wp.com/timberidgegoldendoodles.com/wp-content/uploads/2019/03/HaircutAnatomy.jpg?resize=740%2C740&ssl=1 - as ./images\goldendoodle\a0780becf9.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSKb2ZyhGArFjb_YtkTiphhfutn9Y9gHy_nyA&usqp=CAU - as ./images\goldendoodle\4fa1a8be92.jpg
# SUCCESS - saved https://thumbs.dreamstime.com/b/small-goldendoodle-puppy-sitting-underneath-standing-larger-gold-small-goldendoodle-puppy-woody-sits-upright-underneath-102240005.jpg - as ./images\goldendoodle\1bb2482096.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQgi-3ozpdLlBsA55J509dnJkD1g2h5XmXIFg&usqp=CAU - as ./images\goldendoodle\af19b986f1.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ59PFGexfF0nAH9XWlaZWhSBvGuki2cKTljQ&usqp=CAU - as ./images\goldendoodle\044f02888b.jpg
# SUCCESS - saved https://www.k9rl.com/wp-content/uploads/2020/03/Goldendoodle-dog-running.jpg - as ./images\goldendoodle\245a855b62.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSDZ0BMktzAbQi0I6LzaUVQGCHwFLxq5d-ZiQ&usqp=CAU - as ./images\goldendoodle\375544b7ce.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTDYnBRJggoAzMX6tkehvnLCh8rSdvIx_fHaw&usqp=CAU - as ./images\goldendoodle\82979da522.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQfSp_siGfXS0nppZQyYiDDqGgITker0Z3R4A&usqp=CAU - as ./images\goldendoodle\120f10de0c.jpg
# SUCCESS - saved https://media.ohmy.ca/media/cache/1400x1000/images/5ca4bc2f299501554299951.jpg - as ./images\goldendoodle\5e12de2f3f.jpg
# SUCCESS - saved https://trupanion.com/-/media/trupanion/images/breed--guide--new/goldendoodle/goldendoodle.jpg?la=en&hash=985C7A61D24903FCA35A40EE35B217D2F43F6F9D - as ./images\goldendoodle\d1603c0590.jpg
# SUCCESS - saved https://uptownpuppies.com/wp-content/uploads/2017/05/micro-1.jpg - as ./images\goldendoodle\bc112fd6ac.jpg
