# %%
import os
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"
import keras
# Out:
# Using plaidml.keras.backend backend.

# %%
train_data_directory = 'D:/data science/cats and dogs/train'

# %%
# image data preprocessing
image_size = (112,112)

batch_size = 64


class_mode = 'binary' # for multi-class classification problem, use: class_mode = 'category' 

from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    fill_mode="nearest",
    validation_split=0.2 # set validation split
    ) 

train_generator = train_datagen.flow_from_directory(
    train_data_directory,
    target_size=image_size,
    batch_size=batch_size,
    class_mode=class_mode, # for multi-class classification problem, use 'category'
    subset='training') # set as training data

validation_generator = train_datagen.flow_from_directory(
    train_data_directory, # same directory as training data
    target_size=image_size,
    batch_size=batch_size,
    class_mode=class_mode, # for multi-class classification problem, use 'category'
    subset='validation') # set as validation data
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %%
# build a model
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten, Dropout

VGG_16 = Sequential()
VGG_16.add(Conv2D(input_shape=(112,112,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
VGG_16.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
VGG_16.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

VGG_16.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
VGG_16.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
VGG_16.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

VGG_16.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
VGG_16.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
VGG_16.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
VGG_16.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

VGG_16.add(Flatten())

VGG_16.add(Dense(1024,activation="relu"))
Dropout(0.5)
VGG_16.add(Dense(1024,activation="relu"))
Dropout(0.5)
VGG_16.add(Dense(1, activation="sigmoid"))

VGG_16.summary()
# Out:
# INFO:plaidml:Opening device "opencl_nvidia_geforce_rtx_3080.0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 256)       295168
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 256)       590080
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 256)       590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              51381248
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 54,167,361
# Trainable params: 54,167,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
from keras import optimizers

VGG_16.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics=['acc'])

# %%
# Callbacks
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
checkpoint = ModelCheckpoint("vgg16_dog_cat.h5", 
                             monitor='val_acc', 
                             verbose=1, 
                             save_best_only=True, 
                             save_weights_only=False, 
                             mode='auto', 
                             period=1)
early = EarlyStopping(monitor='val_acc', 
                      min_delta=0, 
                      patience=10, 
                      verbose=1, 
                      mode='auto')
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc',
                                            patience=2,
                                            verbose=1,
                                            factor=0.5,
                                            min_lr=0.0000001)

# %%
# fit/train model

nb_epochs = 1000

history = VGG_16.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = nb_epochs,
    callbacks=[checkpoint, early, learning_rate_reduction])
# Out:
# Epoch 1/1000
# 312/312 [==============================] - 139s 445ms/step - loss: 0.6504 - acc: 0.6147 - val_loss: 0.5884 - val_acc: 0.6821
#
# Epoch 00001: val_acc improved from -inf to 0.68209, saving model to vgg16_dog_cat.h5
# Epoch 2/1000
# 312/312 [==============================] - 118s 379ms/step - loss: 0.5783 - acc: 0.6957 - val_loss: 0.5434 - val_acc: 0.7184
#
# Epoch 00002: val_acc improved from 0.68209 to 0.71840, saving model to vgg16_dog_cat.h5
# Epoch 3/1000
# 312/312 [==============================] - 118s 379ms/step - loss: 0.5356 - acc: 0.7287 - val_loss: 0.5243 - val_acc: 0.7308
#
# Epoch 00003: val_acc improved from 0.71840 to 0.73075, saving model to vgg16_dog_cat.h5
# Epoch 4/1000
# 312/312 [==============================] - 119s 380ms/step - loss: 0.4889 - acc: 0.7618 - val_loss: 0.4725 - val_acc: 0.7753
#
# Epoch 00004: val_acc improved from 0.73075 to 0.77532, saving model to vgg16_dog_cat.h5
# Epoch 5/1000
# 312/312 [==============================] - 118s 378ms/step - loss: 0.4522 - acc: 0.7895 - val_loss: 0.4107 - val_acc: 0.8144
#
# Epoch 00005: val_acc improved from 0.77532 to 0.81442, saving model to vgg16_dog_cat.h5
# Epoch 6/1000
# 312/312 [==============================] - 118s 377ms/step - loss: 0.4198 - acc: 0.8073 - val_loss: 0.4070 - val_acc: 0.8128
#
# Epoch 00006: val_acc did not improve from 0.81442
# Epoch 7/1000
# 312/312 [==============================] - 118s 377ms/step - loss: 0.3877 - acc: 0.8252 - val_loss: 0.3526 - val_acc: 0.8468
#
# Epoch 00007: val_acc improved from 0.81442 to 0.84684, saving model to vgg16_dog_cat.h5
# Epoch 8/1000
# 312/312 [==============================] - 118s 377ms/step - loss: 0.3576 - acc: 0.8424 - val_loss: 0.3964 - val_acc: 0.8252
#
# Epoch 00008: val_acc did not improve from 0.84684
# Epoch 9/1000
# 312/312 [==============================] - 118s 378ms/step - loss: 0.3336 - acc: 0.8527 - val_loss: 0.3689 - val_acc: 0.8345
#
# Epoch 00009: val_acc did not improve from 0.84684
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 10/1000
# 312/312 [==============================] - 117s 376ms/step - loss: 0.2687 - acc: 0.8860 - val_loss: 0.2865 - val_acc: 0.8758
#
# Epoch 00010: val_acc improved from 0.84684 to 0.87581, saving model to vgg16_dog_cat.h5
# Epoch 11/1000
# 312/312 [==============================] - 117s 376ms/step - loss: 0.2521 - acc: 0.8931 - val_loss: 0.2484 - val_acc: 0.8991
#
# Epoch 00011: val_acc improved from 0.87581 to 0.89911, saving model to vgg16_dog_cat.h5
# Epoch 12/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.2422 - acc: 0.8982 - val_loss: 0.2582 - val_acc: 0.8928
#
# Epoch 00012: val_acc did not improve from 0.89911
# Epoch 13/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.2338 - acc: 0.9020 - val_loss: 0.2414 - val_acc: 0.9005
#
# Epoch 00013: val_acc improved from 0.89911 to 0.90053, saving model to vgg16_dog_cat.h5
# Epoch 14/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.2218 - acc: 0.9080 - val_loss: 0.2245 - val_acc: 0.9090
#
# Epoch 00014: val_acc improved from 0.90053 to 0.90904, saving model to vgg16_dog_cat.h5
# Epoch 15/1000
# 312/312 [==============================] - 117s 376ms/step - loss: 0.2135 - acc: 0.9117 - val_loss: 0.2456 - val_acc: 0.8975
#
# Epoch 00015: val_acc did not improve from 0.90904
# Epoch 16/1000
# 312/312 [==============================] - 121s 387ms/step - loss: 0.2013 - acc: 0.9193 - val_loss: 0.2158 - val_acc: 0.9103
#
# Epoch 00016: val_acc improved from 0.90904 to 0.91025, saving model to vgg16_dog_cat.h5
# Epoch 17/1000
# 312/312 [==============================] - 120s 384ms/step - loss: 0.1947 - acc: 0.9210 - val_loss: 0.2195 - val_acc: 0.9072
#
# Epoch 00017: val_acc did not improve from 0.91025
# Epoch 18/1000
# 312/312 [==============================] - 118s 378ms/step - loss: 0.1889 - acc: 0.9207 - val_loss: 0.2049 - val_acc: 0.9163
#
# Epoch 00018: val_acc improved from 0.91025 to 0.91633, saving model to vgg16_dog_cat.h5
# Epoch 19/1000
# 312/312 [==============================] - 120s 383ms/step - loss: 0.1832 - acc: 0.9245 - val_loss: 0.2229 - val_acc: 0.9086
#
# Epoch 00019: val_acc did not improve from 0.91633
# Epoch 20/1000
# 312/312 [==============================] - 120s 386ms/step - loss: 0.1768 - acc: 0.9289 - val_loss: 0.2016 - val_acc: 0.9175
#
# Epoch 00020: val_acc improved from 0.91633 to 0.91754, saving model to vgg16_dog_cat.h5
# Epoch 21/1000
# 312/312 [==============================] - 122s 390ms/step - loss: 0.1755 - acc: 0.9291 - val_loss: 0.1928 - val_acc: 0.9220
#
# Epoch 00021: val_acc improved from 0.91754 to 0.92200, saving model to vgg16_dog_cat.h5
# Epoch 22/1000
# 312/312 [==============================] - 120s 385ms/step - loss: 0.1683 - acc: 0.9306 - val_loss: 0.2363 - val_acc: 0.9026
#
# Epoch 00022: val_acc did not improve from 0.92200
# Epoch 23/1000
# 312/312 [==============================] - 120s 384ms/step - loss: 0.1611 - acc: 0.9345 - val_loss: 0.2065 - val_acc: 0.9167
#
# Epoch 00023: val_acc did not improve from 0.92200
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 24/1000
# 312/312 [==============================] - 119s 383ms/step - loss: 0.1338 - acc: 0.9458 - val_loss: 0.1915 - val_acc: 0.9256
#
# Epoch 00024: val_acc improved from 0.92200 to 0.92565, saving model to vgg16_dog_cat.h5
# Epoch 25/1000
# 312/312 [==============================] - 120s 383ms/step - loss: 0.1303 - acc: 0.9488 - val_loss: 0.1735 - val_acc: 0.9352
#
# Epoch 00025: val_acc improved from 0.92565 to 0.93517, saving model to vgg16_dog_cat.h5
# Epoch 26/1000
# 312/312 [==============================] - 120s 386ms/step - loss: 0.1256 - acc: 0.9504 - val_loss: 0.1907 - val_acc: 0.9279
#
# Epoch 00026: val_acc did not improve from 0.93517
# Epoch 27/1000
# 312/312 [==============================] - 119s 380ms/step - loss: 0.1222 - acc: 0.9515 - val_loss: 0.2179 - val_acc: 0.9220
#
# Epoch 00027: val_acc did not improve from 0.93517
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 28/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.1095 - acc: 0.9555 - val_loss: 0.1798 - val_acc: 0.9325
#
# Epoch 00028: val_acc did not improve from 0.93517
# Epoch 29/1000
# 312/312 [==============================] - 119s 382ms/step - loss: 0.1050 - acc: 0.9591 - val_loss: 0.1975 - val_acc: 0.9287
#
# Epoch 00029: val_acc did not improve from 0.93517
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 30/1000
# 312/312 [==============================] - 119s 380ms/step - loss: 0.0999 - acc: 0.9616 - val_loss: 0.1683 - val_acc: 0.9376
#
# Epoch 00030: val_acc improved from 0.93517 to 0.93760, saving model to vgg16_dog_cat.h5
# Epoch 31/1000
# 312/312 [==============================] - 120s 385ms/step - loss: 0.0965 - acc: 0.9619 - val_loss: 0.1748 - val_acc: 0.9372
#
# Epoch 00031: val_acc did not improve from 0.93760
# Epoch 32/1000
# 312/312 [==============================] - 122s 389ms/step - loss: 0.0964 - acc: 0.9627 - val_loss: 0.1692 - val_acc: 0.9360
#
# Epoch 00032: val_acc did not improve from 0.93760
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 33/1000
# 312/312 [==============================] - 121s 388ms/step - loss: 0.0896 - acc: 0.9661 - val_loss: 0.1810 - val_acc: 0.9340
#
# Epoch 00033: val_acc did not improve from 0.93760
# Epoch 34/1000
# 312/312 [==============================] - 121s 389ms/step - loss: 0.0912 - acc: 0.9645 - val_loss: 0.1764 - val_acc: 0.9348
#
# Epoch 00034: val_acc did not improve from 0.93760
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 35/1000
# 312/312 [==============================] - 116s 373ms/step - loss: 0.0906 - acc: 0.9647 - val_loss: 0.1618 - val_acc: 0.9366
#
# Epoch 00035: val_acc did not improve from 0.93760
# Epoch 36/1000
# 312/312 [==============================] - 123s 394ms/step - loss: 0.0851 - acc: 0.9667 - val_loss: 0.1776 - val_acc: 0.9331
#
# Epoch 00036: val_acc did not improve from 0.93760
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 37/1000
# 312/312 [==============================] - 119s 383ms/step - loss: 0.0871 - acc: 0.9655 - val_loss: 0.1662 - val_acc: 0.9386
#
# Epoch 00037: val_acc improved from 0.93760 to 0.93861, saving model to vgg16_dog_cat.h5
# Epoch 38/1000
# 312/312 [==============================] - 118s 378ms/step - loss: 0.0876 - acc: 0.9663 - val_loss: 0.1646 - val_acc: 0.9433
#
# Epoch 00038: val_acc improved from 0.93861 to 0.94327, saving model to vgg16_dog_cat.h5
# Epoch 39/1000
# 312/312 [==============================] - 120s 384ms/step - loss: 0.0852 - acc: 0.9674 - val_loss: 0.1728 - val_acc: 0.9350
#
# Epoch 00039: val_acc did not improve from 0.94327
# Epoch 40/1000
# 312/312 [==============================] - 122s 391ms/step - loss: 0.0864 - acc: 0.9663 - val_loss: 0.1701 - val_acc: 0.9376
#
# Epoch 00040: val_acc did not improve from 0.94327
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 41/1000
# 312/312 [==============================] - 121s 387ms/step - loss: 0.0874 - acc: 0.9660 - val_loss: 0.1714 - val_acc: 0.9408
#
# Epoch 00041: val_acc did not improve from 0.94327
# Epoch 42/1000
# 312/312 [==============================] - 121s 387ms/step - loss: 0.0877 - acc: 0.9645 - val_loss: 0.1681 - val_acc: 0.9374
#
# Epoch 00042: val_acc did not improve from 0.94327
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 43/1000
# 312/312 [==============================] - 118s 379ms/step - loss: 0.0851 - acc: 0.9670 - val_loss: 0.1662 - val_acc: 0.9400
#
# Epoch 00043: val_acc did not improve from 0.94327
# Epoch 44/1000
# 312/312 [==============================] - 121s 386ms/step - loss: 0.0844 - acc: 0.9676 - val_loss: 0.1705 - val_acc: 0.9394
#
# Epoch 00044: val_acc did not improve from 0.94327
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 45/1000
# 312/312 [==============================] - 126s 405ms/step - loss: 0.0883 - acc: 0.9657 - val_loss: 0.1763 - val_acc: 0.9340
#
# Epoch 00045: val_acc did not improve from 0.94327
# Epoch 46/1000
# 312/312 [==============================] - 135s 433ms/step - loss: 0.0839 - acc: 0.9682 - val_loss: 0.1607 - val_acc: 0.9441
#
# Epoch 00046: val_acc improved from 0.94327 to 0.94408, saving model to vgg16_dog_cat.h5
# Epoch 47/1000
# 312/312 [==============================] - 131s 421ms/step - loss: 0.0865 - acc: 0.9653 - val_loss: 0.1711 - val_acc: 0.9372
#
# Epoch 00047: val_acc did not improve from 0.94408
# Epoch 48/1000
# 312/312 [==============================] - 118s 379ms/step - loss: 0.0851 - acc: 0.9663 - val_loss: 0.1741 - val_acc: 0.9370
#
# Epoch 00048: val_acc did not improve from 0.94408
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 49/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.0857 - acc: 0.9664 - val_loss: 0.1726 - val_acc: 0.9360
#
# Epoch 00049: val_acc did not improve from 0.94408
# Epoch 50/1000
# 312/312 [==============================] - 117s 376ms/step - loss: 0.0879 - acc: 0.9641 - val_loss: 0.1788 - val_acc: 0.9368
#
# Epoch 00050: val_acc did not improve from 0.94408
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 51/1000
# 312/312 [==============================] - 119s 382ms/step - loss: 0.0848 - acc: 0.9683 - val_loss: 0.1760 - val_acc: 0.9352
#
# Epoch 00051: val_acc did not improve from 0.94408
# Epoch 52/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.0843 - acc: 0.9671 - val_loss: 0.1591 - val_acc: 0.9445
#
# Epoch 00052: val_acc improved from 0.94408 to 0.94449, saving model to vgg16_dog_cat.h5
# Epoch 53/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.0882 - acc: 0.9662 - val_loss: 0.1712 - val_acc: 0.9380
#
# Epoch 00053: val_acc did not improve from 0.94449
# Epoch 54/1000
# 312/312 [==============================] - 117s 374ms/step - loss: 0.0880 - acc: 0.9650 - val_loss: 0.1736 - val_acc: 0.9350
#
# Epoch 00054: val_acc did not improve from 0.94449
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 55/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.0878 - acc: 0.9657 - val_loss: 0.1637 - val_acc: 0.9360
#
# Epoch 00055: val_acc did not improve from 0.94449
# Epoch 56/1000
# 312/312 [==============================] - 117s 374ms/step - loss: 0.0845 - acc: 0.9683 - val_loss: 0.1728 - val_acc: 0.9360
#
# Epoch 00056: val_acc did not improve from 0.94449
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 57/1000
# 312/312 [==============================] - 117s 374ms/step - loss: 0.0856 - acc: 0.9659 - val_loss: 0.1737 - val_acc: 0.9396
#
# Epoch 00057: val_acc did not improve from 0.94449
# Epoch 58/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.0852 - acc: 0.9665 - val_loss: 0.1617 - val_acc: 0.9382
#
# Epoch 00058: val_acc did not improve from 0.94449
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 59/1000
# 312/312 [==============================] - 117s 374ms/step - loss: 0.0865 - acc: 0.9663 - val_loss: 0.1844 - val_acc: 0.9356
#
# Epoch 00059: val_acc did not improve from 0.94449
# Epoch 60/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.0872 - acc: 0.9658 - val_loss: 0.1819 - val_acc: 0.9386
#
# Epoch 00060: val_acc did not improve from 0.94449
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 61/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.0838 - acc: 0.9685 - val_loss: 0.1694 - val_acc: 0.9384
#
# Epoch 00061: val_acc did not improve from 0.94449
# Epoch 62/1000
# 312/312 [==============================] - 117s 375ms/step - loss: 0.0829 - acc: 0.9673 - val_loss: 0.1824 - val_acc: 0.9362
#
# Epoch 00062: val_acc did not improve from 0.94449
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 1e-07.
# Epoch 00062: early stopping

# %%
# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'lr'])

# %%
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
